# %%
# !pip install altair pandas openpyxl

# %%
import pandas as pd
import altair as alt

df= pd.read_csv("/chilepib.csv")

# %%
df
# Out:
#                                       Unnamed: 0  N° Bibliotecas Públicas  \
# 0                             Región de Tarapacá                        7
# 1                          Región de Antofagasta                       12
# 2                              Región de Atacama                       12
# 3                             Región de Coquimbo                       21
# 4                           Región de Valparaíso                       36
# 5      Región del Libertador Bernardo O´Higgings                       30
# 6                               Región del Maule                       29
# 7                              Región del Bíobio                       28
# 8                         Región de la Araucanía                       51
# 9                            Región de Los Lagos                       32
# 10                               Región de Aysén                       21
# 11  Región de Magallanes y La Antártica de Chile                        7
# ...

# %%
# @title N° Bibliotecas Públicas vs Préstamos 2023

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='N° Bibliotecas Públicas', y='Préstamos 2023', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Préstamos 2023 vs Personas socias activas

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Préstamos 2023', y='Personas socias activas', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Personas socias activas vs *PIB 2023 (Billones de CLP)

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Personas socias activas', y='*PIB 2023 (Billones de CLP)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
