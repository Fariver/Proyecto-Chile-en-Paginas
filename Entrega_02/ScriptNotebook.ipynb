# %%
import pandas as pd

file_path_1 = '/content/Base de datos - Entrega 2 Gráfica.xlsx'
file_path_2 = '/content/GRÁFICA.xlsx'
file_path_3 = '/content/SNBP_regiones_database.xlsx'
file_path_4 = '/content/Usuarios_prestamos_actividades_database.xlsx'


simce_4to_basico = pd.read_excel(file_path_1, sheet_name='4to básico - SIMCE Lenguaje')
simce_2do_medio = pd.read_excel(file_path_1, sheet_name='2do Medio -SIMCE Lenguaje')
libros_mas_vendidos = pd.read_excel(file_path_1, sheet_name='100 libros más vendidos')


grafica_hoja1 = pd.read_excel(file_path_2, sheet_name='Hoja1')
grafica_hoja2 = pd.read_excel(file_path_2, sheet_name='Hoja2')
grafica_hoja3 = pd.read_excel(file_path_2, sheet_name='Hoja3')


arica_parinacota = pd.read_excel(file_path_3, sheet_name='Arica y Parinacota')
tarapaca = pd.read_excel(file_path_3, sheet_name='Tarapacá')
antofagasta = pd.read_excel(file_path_3, sheet_name='Antofagasta')
atacama = pd.read_excel(file_path_3, sheet_name='Atacama')
coquimbo = pd.read_excel(file_path_3, sheet_name='Coquimbo')
valparaiso = pd.read_excel(file_path_3, sheet_name='Valparaíso')
metropolitana = pd.read_excel(file_path_3, sheet_name='Metropolitana')
ohiggins = pd.read_excel(file_path_3, sheet_name='O’Higgins')
maule = pd.read_excel(file_path_3, sheet_name='Maule')
nuble = pd.read_excel(file_path_3, sheet_name='Ñuble')
biobio = pd.read_excel(file_path_3, sheet_name='Biobío')
araucania = pd.read_excel(file_path_3, sheet_name='La Araucanía')
los_rios = pd.read_excel(file_path_3, sheet_name='Los Ríos')
los_lagos = pd.read_excel(file_path_3, sheet_name='Los Lagos')
aysen = pd.read_excel(file_path_3, sheet_name='Aysén')
magallanes = pd.read_excel(file_path_3, sheet_name='Magallanes')


usuarios = pd.read_excel(file_path_4, sheet_name='USUARIOS')
prestamos = pd.read_excel(file_path_4, sheet_name='PRÉSTAMOS')
actividades = pd.read_excel(file_path_4, sheet_name='ACTIVIDADES')


print("Simce 4to Básico - Lenguaje:")
print(simce_4to_basico.head())

print("\nSimce 2do Medio - Lenguaje:")
print(simce_2do_medio.head())

print("\n100 Libros más vendidos:")
print(libros_mas_vendidos.head())

print("\nHoja1 de GRÁFICA:")
print(grafica_hoja1.head())

print("\nRegión: Arica y Parinacota")
print(arica_parinacota.head())

print("\nUsuarios:")
print(usuarios.head())
# Out:
# Simce 4to Básico - Lenguaje:
#   Puntajes Promedios Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0                NaN   Hombres     Mujeres    GENERAL        NaN         NaN
# 1               2018        267        275        271        NaN         NaN
# 2               2019          -          -        NaN        NaN         NaN
# 3               2020          -          -        NaN        NaN         NaN
# 4               2021          -          -        NaN        NaN         NaN
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# Simce 2do Medio - Lenguaje:
#   Puntajes Promedios Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0                NaN   Hombres     Mujeres    GENERAL        NaN         NaN
# 1               2018        241        256        249        NaN         NaN
# 2               2019          -          -        NaN        NaN         NaN
# ...
